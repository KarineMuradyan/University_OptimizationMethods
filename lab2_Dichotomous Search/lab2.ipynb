# %% [markdown]
# <a href="https://colab.research.google.com/github/KarineMuradyan/University_OptimizationMethods/blob/main/lab2_Dichotomous%20Search/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Objective function
def f(x):
    return 0.25 * x**4 + x**2 - 8*x + 12

# Parameters
a = 0
b = 2
epsilon = 0.05
delta = 0.01
all_x = []
all_y = []

# Table Header
print(f"{'Iter':<5} {'a':<10} {'b':<10} {'x1':<10} {'x2':<10} {'f(x1)':<10} {'f(x2)':<10}")
print("-" * 75)

# 2. Dichotomous Search Method with Step-by-Step Output
k = 0
while (b - a) > epsilon:
    x1 = (a + b - delta) / 2
    x2 = (a + b + delta) / 2
    f1, f2 = f(x1), f(x2)

    # Store for plotting
    all_x.extend([x1, x2])
    all_y.extend([f1, f2])

    # Print current step results
    print(f"{k:<5} {a:<10.4f} {b:<10.4f} {x1:<10.4f} {x2:<10.4f} {f1:<10.4f} {f2:<10.4f}")

    if f1 <= f2:
        b = x2
    else:
        a = x1
    k += 1

# Final Result
x_star = (a + b) / 2
print("-" * 75)
print(f"Final Minimum Point: x* ≈ {x_star:.4f}")
print(f"Function Value at Minimum: f(x*) ≈ {f(x_star):.4f}")

# 3. Visualization
x_vals = np.linspace(-0.5, 2.5, 500)
y_vals = f(x_vals)

plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_vals, label='f(x)', color='blue', linewidth=2)
plt.scatter(all_x, all_y, color='red', s=40, zorder=5, label='Calculated points')
plt.axvline(x_star, color='green', linestyle='--', alpha=0.7, label=f'Minimum (x ≈ {x_star:.3f})')

plt.title('Dichotomous Search')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Iter  a          b          x1         x2         f(x1)      f(x2)
# ---------------------------------------------------------------------------
# 0     0.0000     2.0000     0.9950     1.0050     5.2751     5.2251
# 1     0.9950     2.0000     1.4925     1.5025     3.5281     3.5116
# 2     1.4925     2.0000     1.7413     1.7512     3.4001     3.4083
# 3     1.4925     1.7512     1.6169     1.6269     3.3879     3.3830
# 4     1.6169     1.7512     1.6791     1.6891     3.3738     3.3752
# 5     1.6169     1.6891     1.6480     1.6580     3.3759     3.3742
# ---------------------------------------------------------------------------
# Final Minimum Point: x* ≈ 1.6685
# Function Value at Minimum: f(x*) ≈ 3.3734
